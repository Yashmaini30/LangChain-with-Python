# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
res = llm.invoke("Explain the theory of relativity in simple terms.")
print(res.content)
# Out:
# Imagine you're on a train, and you throw a ball straight up in the air. To you, the ball goes up and comes straight back down into your hand. Easy, right?
#
# Now, imagine someone standing on the ground watching your train zoom by. To them, the ball doesn't just go up and down. It travels in a curved path, like a rainbow, because the train is moving forward while the ball is in the air.
#
# This simple example hints at the core idea of **relativity**: **how we observe things depends on our own motion.**
#
# Albert Einstein's theory of relativity is actually two theories:
#
# **1. Special Relativity (published in 1905):**
#
# This theory deals with motion at **constant speeds** (no acceleration). Its two main pillars are:
#
# ...

# %% [markdown]
# ### Static prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
### Static prompts
promts = [
    ("system", "You are a helpful assistant that explains concepts as python code."),
    ("user", "Explain the theory of relativity in simple terms.")
]

response = llm.invoke(promts)
print(response.content)
# Out:
# The theory of relativity, developed by Albert Einstein, is actually two theories: **Special Relativity** and **General Relativity**. They revolutionized our understanding of space, time, gravity, and the universe.
#
# Let's break them down with Python analogies:
#
# ## 1. Special Relativity (1905)
#
# Special relativity deals with **motion at constant speeds** (no acceleration) and how it affects space and time. The two core ideas are:
#
# *   **The laws of physics are the same for all non-accelerating observers.**
#     *   Imagine you're in a perfectly smooth-riding train moving at a constant speed. If you drop a ball, it falls straight down, just like it would if you were standing still on the ground. You can't tell you're moving without looking out the window.
#
#     ```python
#     # Analogy: Imagine two observers, Alice and Bob.
#     # Alice is standing still.
#     alice_position = 0
#     alice_velocity = 0
#
#     # Bob is on a train moving at a constant speed.
# ...
